# %% [markdown]
# <a href="https://colab.research.google.com/github/Ac13557/115-1/blob/main/411452036_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello\nHello")
# Out:
# Hello
# Hello

# %%
x=50000*(1+0.015)**5
print(x)
# Out:
# 53864.20019421873
